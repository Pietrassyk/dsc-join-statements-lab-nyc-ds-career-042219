# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
#Your code here
import pandas as pd
import sqlite3
conn = sqlite3.connect("data.sqlite")
c = conn.cursor()

# %%
def sql (querry ,cursor = c):
    """Runs a SQL querry and returns results as a Dataframe. cursor Variable is set to 'c' by default. Make sure your run sql_connect before using or set cursor manually """
    c.execute(querry)
    c.fetchall
    df = pd.DataFrame(c.fetchall())
    df.columns = [x[0] for x in c.description]
    return df

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and customers tables.

# %%
sql("""select * from sqlite_master""")
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table  orderdetails  orderdetails         2
# 1  table      payments      payments        28
# 2  table       offices       offices        32
# 3  table     customers     customers        33
# 4  table        orders        orders        38
# 5  table  productlines  productlines        46
# 6  table      products      products        47
# 7  table     employees     employees        56
#
#                                                  sql
# 0  CREATE TABLE `orderdetails` (`orderNumber`, `p...
# 1  CREATE TABLE `payments` (`customerNumber`, `ch...
# 2  CREATE TABLE `offices` (`officeCode`, `city`, ...
# 3  CREATE TABLE `customers` (`customerNumber`, `c...
# 4  CREATE TABLE `orders` (`orderNumber`, `orderDa...
# 5  CREATE TABLE `productlines` (`productLine`, `t...
# 6  CREATE TABLE `products` (`productCode`, `produ...
# 7  CREATE TABLE `employees` (`employeeNumber`, `l...

# %%
#Your code here
sql("""select lastName,firstName 
from 
employees as e join offices as o 
on e.officeCode = o.officeCode 
where city = "Boston";""")
# Out:
#     lastName firstName
# 0   Firrelli     Julie
# 1  Patterson     Steve

# %% [markdown]
# ## Do any offices have no employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
#Your code here
# Out:
# OperationalErrorTraceback (most recent call last)
# <ipython-input-9-72decd1edb00> in <module>()
#       4 customers as c join employees as e
#       5 on c.salesRepEmployeeNumber = e.employeeNumber as ce
# ----> 6 """)
#
# <ipython-input-3-c0e2330d125d> in sql(querry, cursor)
#       1 def sql (querry ,cursor = c):
#       2     """Runs a SQL querry and returns results as a Dataframe. cursor Variable is set to 'c' by default. Make sure your run sql_connect before using or set cursor manually """
# ----> 3     c.execute(querry)
#       4     c.fetchall
#       5     df = pd.DataFrame(c.fetchall())
#
# OperationalError: near "as": syntax error

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
sql(""" select lastName, firstName, productName from employees
            join customers
            on employees.employeeNumber = customers.salesRepEmployeeNumber
            join orders
            on customers.customerNumber = orders.customerNumber
            join orderdetails
            on orders.orderNumber = orderdetails.orderNumber
            join products
            on orderdetails.productCode = products.productCode""")
# Out:
#       lastName firstName                                  productName
# 0     Jennings    Leslie                               1958 Setra Bus
# 1     Jennings    Leslie                       1940 Ford Pickup Truck
# 2     Jennings    Leslie                      1939 Cadillac Limousine
# 3     Jennings    Leslie  1996 Peterbilt 379 Stake Bed with Outrigger
# 4     Jennings    Leslie                            1968 Ford Mustang
# 5     Jennings    Leslie                           1968 Dodge Charger
# 6     Jennings    Leslie                      1970 Plymouth Hemi Cuda
# 7     Jennings    Leslie                           1969 Dodge Charger
# 8     Jennings    Leslie                  1948 Porsche 356-A Roadster
# 9     Jennings    Leslie                         1969 Dodge Super Bee
